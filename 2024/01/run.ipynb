# %%
L, R = zip(*((map(int, line.split('   '))) for line in open('input.txt')))
part1 = sum(abs(l-r) for l,r in zip(sorted(L),sorted(R)))
print(part1)
# Out:
# 2769675

# %%
from collections import Counter

cR = Counter(R)
part2 = sum(l*cR[l] for l in L)
print(part2)
# Out:
# 24643097
